# %%
# pip install qiskit==0.31.0

# %%
import qiskit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, BasicAer
import numpy as np
from qiskit.visualization import plot_histogram

def custom_qft(data_qubits):
    qr_data = QuantumRegister(data_qubits)
    cr_data = ClassicalRegister(data_qubits)
    qc = QuantumCircuit(qr_data,cr_data)
    i = data_qubits
    while i>=1:
        n = i - 1
        qc.h(qr_data[n]) 
        for qubit in range(n):
            qc.cp(np.pi/2**(n-qubit), qr_data[qubit], qr_data[n])
        i = i-1
    return qc


def subroutine_add_const(data_qubits, const):
    qc = QuantumCircuit(data_qubits)

    for i in range(data_qubits):
        angle = const*np.pi/(2**i)
        qc.p(angle,i)

    return qc

# %%
qc = custom_qft(7)
qc.draw(output='mpl')

# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
from Customize_OneHot import *
from Dataset_functions import *
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import keras.backend as K
from keras.layers import Input, Dense, Dropout
from keras.models import Model
from keras.utils import plot_model


np.random.seed(123)
tf.random.set_seed(123)
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("dataset/dataset_tesi/NN1_Dataset(<=10Cx)_balanced1.csv")

# %%
display(df.groupby('1').count())
# Out:
#    Unnamed: 0  last_update_date  backend_name  N_qubtis  N_cx  N_measure  \
# 1
# 1         853               853           853       853   853        853
# 2           5                 5             5         5     5          5
# 3           4                 4             4         4     4          4
# 4           3                 3             3         3     3          3
# 5         228               228           228       228   228        228
# 6           5                 5             5         5     5          5
#
#    cx_01  cx_02  cx_03  cx_04  ...  readout_error_5  T1_6  T2_6  \
# 1                              ...
# 1    853    853    853    853  ...              853   853   853
# 2      5      5      5      5  ...                5     5     5
# 3      4      4      4      4  ...                4     4     4
# 4      3      3      3      3  ...                3     3     3
# 5    228    228    228    228  ...              228   228   228
# 6      5      5      5      5  ...                5     5     5
#
#    readout_error_6    0    2    3    4    5    6
# 1
# 1              853  853  853  853  853  853  853
# 2                5    5    5    5    5    5    5
# 3                4    4    4    4    4    4    4
# 4                3    3    3    3    3    3    3
# 5              228  228  228  228  228  228  228
# 6                5    5    5    5    5    5    5
#
# [6 rows x 166 columns]

# %%
df1 = df.groupby('0').count()
# display(df1.index)
display(df1.iloc[:,0])#.values
new_df = df1.iloc[:,0]
for i in range(7):
    if i not in new_df.keys():
        new_df[i] = 0
new_df.keys(), new_df, list(dict(sorted(new_df.items())).values())
# Out:
# 0
# 0    571
# 2    277
# 3     27
# 4     32
# 6    191
# Name: Unnamed: 0, dtype: int64
# (Index([0, 2, 3, 4, 6, 1, 5], dtype='int64', name='0'),
#  0
#  0    571
#  2    277
#  3     27
#  4     32
#  6    191
#  1      0
#  5      0
#  Name: Unnamed: 0, dtype: int64,
#  [571, 0, 277, 27, 32, 0, 191])

# %%
for c in df.columns:
    print(c)
# Out:
# Unnamed: 0
# last_update_date
# backend_name
# N_qubtis
# N_cx
# N_measure
# cx_01
# cx_02
# cx_03
# cx_04
# cx_05
# cx_06
# cx_10
# cx_12
# cx_13
# cx_14
# cx_15
# cx_16
# cx_20
# cx_21
# cx_23
# cx_24
# cx_25
# cx_26
# cx_30
# cx_31
# cx_32
# cx_34
# cx_35
# cx_36
# cx_40
# cx_41
# cx_42
# cx_43
# cx_45
# cx_46
# cx_50
# cx_51
# cx_52
# cx_53
# cx_54
# cx_56
# cx_60
# cx_61
# cx_62
# cx_63
# cx_64
# cx_65
# measure_0
# measure_1
# measure_2
# measure_3
# measure_4
# measure_5
# measure_6
# edge_error_01
# edge_length_01
# edge_error_02
# edge_length_02
# edge_error_03
# edge_length_03
# edge_error_04
# edge_length_04
# edge_error_05
# edge_length_05
# edge_error_06
# edge_length_06
# edge_error_10
# edge_length_10
# edge_error_12
# edge_length_12
# edge_error_13
# edge_length_13
# edge_error_14
# edge_length_14
# edge_error_15
# edge_length_15
# edge_error_16
# edge_length_16
# edge_error_20
# edge_length_20
# edge_error_21
# edge_length_21
# edge_error_23
# edge_length_23
# edge_error_24
# edge_length_24
# edge_error_25
# edge_length_25
# edge_error_26
# edge_length_26
# edge_error_30
# edge_length_30
# edge_error_31
# edge_length_31
# edge_error_32
# edge_length_32
# edge_error_34
# edge_length_34
# edge_error_35
# edge_length_35
# edge_error_36
# edge_length_36
# edge_error_40
# edge_length_40
# edge_error_41
# edge_length_41
# edge_error_42
# edge_length_42
# edge_error_43
# edge_length_43
# edge_error_45
# edge_length_45
# edge_error_46
# edge_length_46
# edge_error_50
# edge_length_50
# edge_error_51
# edge_length_51
# edge_error_52
# edge_length_52
# edge_error_53
# edge_length_53
# edge_error_54
# edge_length_54
# edge_error_56
# edge_length_56
# edge_error_60
# edge_length_60
# edge_error_61
# edge_length_61
# edge_error_62
# edge_length_62
# edge_error_63
# edge_length_63
# edge_error_64
# edge_length_64
# edge_error_65
# edge_length_65
# T1_0
# T2_0
# readout_error_0
# T1_1
# T2_1
# readout_error_1
# T1_2
# T2_2
# readout_error_2
# T1_3
# T2_3
# readout_error_3
# T1_4
# T2_4
# readout_error_4
# T1_5
# T2_5
# readout_error_5
# T1_6
# T2_6
# readout_error_6
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
df.shape
# Out:
# (12, 167)

# %%
def clear_dataset(df, n_qubits):
    df = df.drop_duplicates()
    for i in range(n_qubits):
        df = df.drop('measure_' + str(i), axis=1)
    # Histo_Dataset(df, N_qubits=n_qubits)
    #Rimozione Features non interessanti
    df = df.drop('N_measure', axis = 1)
    # TO DO
    # remove edges which are not in coupling maps
    connections = ['01','10','12','21','13','31','35','53','45','54','56','65']
    to_keep = []
    for c in connections:
        to_keep.append("edge_error_"+c)    
        to_keep.append("edge_length_"+c)
    to_drop = []
    for c in df.columns:
        if "edge_error" in c or "edge_length" in c:
            if c not in to_keep:
                to_drop.append(c)
    df = df.drop(to_drop,axis=1)
    return df

# %%
df = clear_dataset(df, 7)


last_7 = len(df.columns)-7
X = df.iloc[:, 3:last_7].values
y = df.iloc[:, last_7:].values

# %%
X.shape,y.shape, len(X), len(y)
# Out:
# ((12, 89), (12, 7), 12, 12)

# %%
for c in df.columns:
    print(c)
# Out:
# Unnamed: 0
# last_update_date
# backend_name
# N_qubtis
# N_cx
# N_measure
# cx_01
# cx_02
# cx_03
# cx_04
# cx_05
# cx_06
# cx_10
# cx_12
# cx_13
# cx_14
# cx_15
# cx_16
# cx_20
# cx_21
# cx_23
# cx_24
# cx_25
# cx_26
# cx_30
# cx_31
# cx_32
# cx_34
# cx_35
# cx_36
# cx_40
# cx_41
# cx_42
# cx_43
# cx_45
# cx_46
# cx_50
# cx_51
# cx_52
# cx_53
# cx_54
# cx_56
# cx_60
# cx_61
# cx_62
# cx_63
# cx_64
# cx_65
# measure_0
# measure_1
# measure_2
# measure_3
# measure_4
# measure_5
# measure_6
# edge_error_01
# edge_length_01
# edge_error_02
# edge_length_02
# edge_error_03
# edge_length_03
# edge_error_04
# edge_length_04
# edge_error_05
# edge_length_05
# edge_error_06
# edge_length_06
# edge_error_10
# edge_length_10
# edge_error_12
# edge_length_12
# edge_error_13
# edge_length_13
# edge_error_14
# edge_length_14
# edge_error_15
# edge_length_15
# edge_error_16
# edge_length_16
# edge_error_20
# edge_length_20
# edge_error_21
# edge_length_21
# edge_error_23
# edge_length_23
# edge_error_24
# edge_length_24
# edge_error_25
# edge_length_25
# edge_error_26
# edge_length_26
# edge_error_30
# edge_length_30
# edge_error_31
# edge_length_31
# edge_error_32
# edge_length_32
# edge_error_34
# edge_length_34
# edge_error_35
# edge_length_35
# edge_error_36
# edge_length_36
# edge_error_40
# edge_length_40
# edge_error_41
# edge_length_41
# edge_error_42
# edge_length_42
# edge_error_43
# edge_length_43
# edge_error_45
# edge_length_45
# edge_error_46
# edge_length_46
# edge_error_50
# edge_length_50
# edge_error_51
# edge_length_51
# edge_error_52
# edge_length_52
# edge_error_53
# edge_length_53
# edge_error_54
# edge_length_54
# edge_error_56
# edge_length_56
# edge_error_60
# edge_length_60
# edge_error_61
# edge_length_61
# edge_error_62
# edge_length_62
# edge_error_63
# edge_length_63
# edge_error_64
# edge_length_64
# edge_error_65
# edge_length_65
# T1_0
# T2_0
# readout_error_0
# T1_1
# T2_1
# readout_error_1
# T1_2
# T2_2
# readout_error_2
# T1_3
# T2_3
# readout_error_3
# T1_4
# T2_4
# readout_error_4
# T1_5
# T2_5
# readout_error_5
# T1_6
# T2_6
# readout_error_6
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
connections = ['01','10','12','21','13','31','35','53','45','54','56','65']
to_keep = []
for c in connections:
    to_keep.append("edge_error_"+c)    
    to_keep.append("edge_length_"+c)
to_keep
# Out:
# ['edge_error_01',
#  'edge_length_01',
#  'edge_error_10',
#  'edge_length_10',
#  'edge_error_12',
#  'edge_length_12',
#  'edge_error_21',
#  'edge_length_21',
#  'edge_error_13',
#  'edge_length_13',
#  'edge_error_31',
#  'edge_length_31',
#  'edge_error_35',
#  'edge_length_35',
#  'edge_error_53',
#  'edge_length_53',
#  'edge_error_45',
#  'edge_length_45',
#  'edge_error_54',
#  'edge_length_54',
#  'edge_error_56',
#  'edge_length_56',
#  'edge_error_65',
#  'edge_length_65']

# %%
to_drop = []
for c in df.columns:
    if "edge_error" in c or "edge_length" in c:
        if c not in to_keep:
            to_drop.append(c)
to_drop
# Out:
# ['edge_error_02',
#  'edge_length_02',
#  'edge_error_03',
#  'edge_length_03',
#  'edge_error_04',
#  'edge_length_04',
#  'edge_error_05',
#  'edge_length_05',
#  'edge_error_06',
#  'edge_length_06',
#  'edge_error_14',
#  'edge_length_14',
#  'edge_error_15',
#  'edge_length_15',
#  'edge_error_16',
#  'edge_length_16',
#  'edge_error_20',
#  'edge_length_20',
#  'edge_error_23',
#  'edge_length_23',
#  'edge_error_24',
#  'edge_length_24',
#  'edge_error_25',
#  'edge_length_25',
#  'edge_error_26',
#  'edge_length_26',
#  'edge_error_30',
#  'edge_length_30',
#  'edge_error_32',
#  'edge_length_32',
#  'edge_error_34',
#  'edge_length_34',
#  'edge_error_36',
#  'edge_length_36',
#  'edge_error_40',
#  'edge_length_40',
#  'edge_error_41',
#  'edge_length_41',
#  'edge_error_42',
#  'edge_length_42',
#  'edge_error_43',
#  'edge_length_43',
#  'edge_error_46',
#  'edge_length_46',
#  'edge_error_50',
#  'edge_length_50',
#  'edge_error_51',
#  'edge_length_51',
#  'edge_error_52',
#  'edge_length_52',
#  'edge_error_60',
#  'edge_length_60',
#  'edge_error_61',
#  'edge_length_61',
#  'edge_error_62',
#  'edge_length_62',
#  'edge_error_63',
#  'edge_length_63',
#  'edge_error_64',
#  'edge_length_64']

# %%
import os

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory
